# %%
#Data Analytics Project1

# %%
#used some of python libraries to analyze data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
#pip install plotly and used plotly libraiers

# %%
import plotly.plotly as py
#import plotly.offline as offline
import plotly.graph_objs as go
#from IPython.display import Image

# %%
#load census data and convert into a data frame
census_data = os.path.join('Data Sets',"acs2015_census_tract_data.csv")
census_df = pd.read_csv(census_data, skipinitialspace = True,low_memory = False)
census_df.head()
# Out:
#    CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0   1001020100  Alabama  Autauga      1948   940   1008       0.9   87.4
# 1   1001020200  Alabama  Autauga      2156  1059   1097       0.8   40.4
# 2   1001020300  Alabama  Autauga      2968  1364   1604       0.0   74.5
# 3   1001020400  Alabama  Autauga      4423  2172   2251      10.5   82.8
# 4   1001020500  Alabama  Autauga     10763  4922   5841       0.7   68.5
#
#    Black  Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0    7.7     0.3      ...        0.5          2.3         2.1         25.0
# 1   53.3     0.0      ...        0.0          0.7         0.0         23.4
# 2   18.6     0.5      ...        0.0          0.0         2.5         19.6
# 3    3.7     1.6      ...        0.0          2.6         1.6         25.3
# 4   24.8     0.0      ...        0.0          0.6         0.9         24.8
#
# ...

# %%
#load air quality index data to csv
air_quality_data = os.path.join('Data Sets',"Air_Quality_data.csv")
air_quality_df = pd.read_csv(air_quality_data, skipinitialspace = True)
air_quality_df.head()
# Out:
#    MeasureId                                        MeasureName MeasureType  \
# 0         83  Number of days with maximum 8-hour average ozo...      Counts
# 1         83  Number of days with maximum 8-hour average ozo...      Counts
# 2         83  Number of days with maximum 8-hour average ozo...      Counts
# 3         83  Number of days with maximum 8-hour average ozo...      Counts
# 4         83  Number of days with maximum 8-hour average ozo...      Counts
#
#   StratificationLevel  StateFips StateName  CountyFips CountyName  ReportYear  \
# 0      State x County          1   Alabama        1051     Elmore        1999
# 1      State x County          1   Alabama        1073  Jefferson        1999
# 2      State x County          1   Alabama        1079   Lawrence        1999
# 3      State x County          1   Alabama        1089    Madison        1999
# 4      State x County          1   Alabama        1097     Mobile        1999
#
# ...

# %%
# Renamed some of columns in AQI data frame
#renamed_df = air_quality_df.rename(columns={"StateName":"State",
                                            #"CountyName":"County"})
#renamed_df.head()

# %%
measure_83 = air_quality_df.loc[air_quality_df['MeasureId']==83]
measure_83.head()
# Out:
#    MeasureId                                        MeasureName MeasureType  \
# 0         83  Number of days with maximum 8-hour average ozo...      Counts
# 1         83  Number of days with maximum 8-hour average ozo...      Counts
# 2         83  Number of days with maximum 8-hour average ozo...      Counts
# 3         83  Number of days with maximum 8-hour average ozo...      Counts
# 4         83  Number of days with maximum 8-hour average ozo...      Counts
#
#   StratificationLevel  StateFips StateName  CountyFips CountyName  ReportYear  \
# 0      State x County          1   Alabama        1051     Elmore        1999
# 1      State x County          1   Alabama        1073  Jefferson        1999
# 2      State x County          1   Alabama        1079   Lawrence        1999
# 3      State x County          1   Alabama        1089    Madison        1999
# 4      State x County          1   Alabama        1097     Mobile        1999
#
# ...

# %%
year2015 = measure_83.iloc[:,[0,1,5,8,9]]
year2015.head()
# Out:
#    MeasureId                                        MeasureName StateName  \
# 0         83  Number of days with maximum 8-hour average ozo...   Alabama
# 1         83  Number of days with maximum 8-hour average ozo...   Alabama
# 2         83  Number of days with maximum 8-hour average ozo...   Alabama
# 3         83  Number of days with maximum 8-hour average ozo...   Alabama
# 4         83  Number of days with maximum 8-hour average ozo...   Alabama
#
#    ReportYear  Value
# 0        1999    5.0
# 1        1999   39.0
# 2        1999   28.0
# 3        1999   31.0
# 4        1999   32.0

# %%
measure1 = air_quality_df['ReportYear'].unique()
measure1
# Out:
# array([1999, 2013, 2002, 2003, 2007, 2008, 2004, 2012, 2000, 2001, 2005,
#        2006, 2009, 2011, 2010], dtype=int64)

# %%
measure85 = air_quality_df.loc[air_quality_df['MeasureId']==85]
measure85.head()
# Out:
#      MeasureId                                        MeasureName MeasureType  \
# 48          85  Percent of days with PM2.5 levels over the Nat...     Percent
# 73          85  Percent of days with PM2.5 levels over the Nat...     Percent
# 318         85  Percent of days with PM2.5 levels over the Nat...     Percent
# 343         85  Percent of days with PM2.5 levels over the Nat...     Percent
# 392         85  Percent of days with PM2.5 levels over the Nat...     Percent
#
#     StratificationLevel  StateFips   StateName  CountyFips CountyName  \
# 48       State x County         40    Oklahoma       40143      Tulsa
# 73       State x County         39        Ohio       39151      Stark
# 318      State x County         35  New Mexico       35025        Lea
# 343      State x County         48       Texas       48037      Bowie
# 392      State x County          4     Arizona        4003    Cochise
#
#      ReportYear  Value Unit UnitName    DataOrigin  MonitorOnly
# ...

# %%
m1 = measure85.iloc[:,[0,1,2,5,8,9,10]]
m1.head()
# Out:
#      MeasureId                                        MeasureName MeasureType  \
# 48          85  Percent of days with PM2.5 levels over the Nat...     Percent
# 73          85  Percent of days with PM2.5 levels over the Nat...     Percent
# 318         85  Percent of days with PM2.5 levels over the Nat...     Percent
# 343         85  Percent of days with PM2.5 levels over the Nat...     Percent
# 392         85  Percent of days with PM2.5 levels over the Nat...     Percent
#
#       StateName  ReportYear  Value Unit
# 48     Oklahoma        1999    0.0    %
# 73         Ohio        2013    0.0    %
# 318  New Mexico        2002    0.0    %
# 343       Texas        2003    0.0    %
# 392     Arizona        2007    0.0    %

# %%
m1_average=m1.groupby(['StateName','ReportYear'])[['Value']].mean()
#m1_average.head
#gradeReading = students_df1.groupby(['grade','school'])[['reading_score']].mean() 
#each_school_df["math_score"].groupby(each_school_df["school"]).mean()

# %%
m1_df=pd.DataFrame(m1_average)
m1_df.head()
# Out:
#                          Value
# StateName ReportYear
# Alabama   1999        7.413717
#           2000        4.517422
#           2001        0.818434
#           2002        0.821736
#           2003        0.914094

# %%
measure_df = m1_df.reset_index()
measure_df.head()
# Out:
#   StateName  ReportYear     Value
# 0   Alabama        1999  7.413717
# 1   Alabama        2000  4.517422
# 2   Alabama        2001  0.818434
# 3   Alabama        2002  0.821736
# 4   Alabama        2003  0.914094

# %%
state_col = measure_df['StateName']
year_col = measure_df['ReportYear']

value_col = measure_df['Value']
value_plot= go.Bar(x = state_col, y = value_col, name = year_col,
                   marker=dict(color='rgb(158,202,225)'))
layout = dict(title = 'Air Quality Index Value(PM2.5) By State',
              xaxis = dict(title = 'State'),
              yaxis = dict(title = 'AQI Value'),
              )
data = [value_plot]
fig = dict(data=data,layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yamini/331.embed" height="525px" width="100%"></iframe>

# %%
measure83_average=measure_83.groupby(['StateName','ReportYear'])[['Value']].mean()
measure83_average
measure83=pd.DataFrame(measure83_average)
measure83.head()
# Out:
#                           Value
# StateName ReportYear
# Alabama   1999        25.666667
#           2000        21.600000
#           2001         7.333333
#           2002        10.400000
#           2003         5.312500

# %%
year_2003=measure_83.loc[measure_83['ReportYear']==2013]
year_2003.head()
# Out:
#        MeasureId                                        MeasureName  \
# 19250         83  Number of days with maximum 8-hour average ozo...
# 19251         83  Number of days with maximum 8-hour average ozo...
# 19252         83  Number of days with maximum 8-hour average ozo...
# 19253         83  Number of days with maximum 8-hour average ozo...
# 19254         83  Number of days with maximum 8-hour average ozo...
#
#       MeasureType StratificationLevel  StateFips StateName  CountyFips  \
# 19250      Counts      State x County          1   Alabama        1003
# 19251      Counts      State x County          1   Alabama        1033
# 19252      Counts      State x County          1   Alabama        1049
# 19253      Counts      State x County          1   Alabama        1051
# 19254      Counts      State x County          1   Alabama        1055
#
#       CountyName  ReportYear  Value      Unit  UnitName    DataOrigin  \
# ...

# %%
year2003_average=year_2003.groupby(['StateName'])[['Value']].mean()
year2003_average.head()
year2003=pd.DataFrame(year2003_average)
year2003.head()
# Out:
#                 Value
# StateName
# Alabama      0.066667
# Alaska       0.000000
# Arizona      2.222222
# Arkansas     0.000000
# California  11.479167

# %%
year2003_df = year2003.reset_index()
year2003_df.head()
# Out:
#     StateName      Value
# 0     Alabama   0.066667
# 1      Alaska   0.000000
# 2     Arizona   2.222222
# 3    Arkansas   0.000000
# 4  California  11.479167

# %%
measure83_df = measure83.reset_index()
measure83_df.head()
# Out:
#   StateName  ReportYear      Value
# 0   Alabama        1999  25.666667
# 1   Alabama        2000  21.600000
# 2   Alabama        2001   7.333333
# 3   Alabama        2002  10.400000
# 4   Alabama        2003   5.312500

# %%
state_col = measure83_df['StateName']
year_col = measure83_df['ReportYear']

value_col = measure83_df['Value']
value_plot= go.Bar(x = state_col, y = value_col, name = year_col,
                   marker=dict(color='rgb(158,202,225)'))
layout = dict(title = 'Air Quality Index Value(OZ Concentration) By State',
              xaxis = dict(title = 'State'),
              yaxis = dict(title = 'AQI Value'),
              )
data = [value_plot]
fig = dict(data=data,layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yamini/333.embed" height="525px" width="100%"></iframe>

# %%
average_income = census_df[['Income','IncomeErr','IncomePerCap',
                                  'IncomePerCapErr',]].groupby(census_df['State']).mean()
average_income.head()
# Out:
#                   Income     IncomeErr  IncomePerCap  IncomePerCapErr
# State
# Alabama     43296.358603   7644.020443  22840.097021      3360.434043
# Alaska      70354.743902   9743.567073  33003.228916      4417.463855
# Arizona     54207.820955   9049.810345  26363.113891      3882.750494
# Arkansas    41935.633968   7056.516837  22126.816058      3212.827737
# California  67264.782303  11220.131976  31154.595604      4423.282503

# %%
income_df = average_income.reset_index()
income_df.head()
# Out:
#         State        Income     IncomeErr  IncomePerCap  IncomePerCapErr
# 0     Alabama  43296.358603   7644.020443  22840.097021      3360.434043
# 1      Alaska  70354.743902   9743.567073  33003.228916      4417.463855
# 2     Arizona  54207.820955   9049.810345  26363.113891      3882.750494
# 3    Arkansas  41935.633968   7056.516837  22126.816058      3212.827737
# 4  California  67264.782303  11220.131976  31154.595604      4423.282503

# %%
#converting average_income group by object to data frame
#average_income_df = pd.DataFrame(average_income)
income_df = average_income.reset_index()
income_df.head()
# Out:
#         State        Income     IncomeErr  IncomePerCap  IncomePerCapErr
# 0     Alabama  44926.578126   7817.443544  23540.089354      3434.193292
# 1      Alaska  70354.743902   9743.567073  33003.228916      4417.463855
# 2     Arizona  55129.033880   9147.338518  26754.109831      3921.427871
# 3    Arkansas  42522.719719   7218.073758  22541.566124      3323.808522
# 4  California  67244.318798  11206.935181  31049.519125      4402.010551

# %%
average_income_df = pd.DataFrame(income_df)
average_income_df.head()
# Out:
#         State        Income     IncomeErr  IncomePerCap  IncomePerCapErr
# 0     Alabama  43296.358603   7644.020443  22840.097021      3360.434043
# 1      Alaska  70354.743902   9743.567073  33003.228916      4417.463855
# 2     Arizona  54207.820955   9049.810345  26363.113891      3882.750494
# 3    Arkansas  41935.633968   7056.516837  22126.816058      3212.827737
# 4  California  67264.782303  11220.131976  31154.595604      4423.282503

# %%
year2003_df = year2003.reset_index()
year2003_df.head()
# Out:
#     StateName      Value
# 0     Alabama   0.066667
# 1      Alaska   0.000000
# 2     Arizona   2.222222
# 3    Arkansas   0.000000
# 4  California  11.479167

# %%
year2003_df = year2003_df.rename(columns={"StateName":"State"
                                            })
year2003_df.head()
# Out:
#         State      Value
# 0     Alabama   0.066667
# 1      Alaska   0.000000
# 2     Arizona   2.222222
# 3    Arkansas   0.000000
# 4  California  11.479167

# %%
merged_data_df = pd.merge(year2003_df,average_income_df,on=['State'],how='outer')
merged_data_df.head()
# Out:
#         State      Value        Income     IncomeErr  IncomePerCap  \
# 0     Alabama   0.066667  43296.358603   7644.020443  22840.097021
# 1      Alaska   0.000000  70354.743902   9743.567073  33003.228916
# 2     Arizona   2.222222  54207.820955   9049.810345  26363.113891
# 3    Arkansas   0.000000  41935.633968   7056.516837  22126.816058
# 4  California  11.479167  67264.782303  11220.131976  31154.595604
#
#    IncomePerCapErr
# 0      3360.434043
# 1      4417.463855
# 2      3882.750494
# 3      3212.827737
# 4      4423.282503

# %%
trace1 = go.Bar(
    x= merged_data_df['State'],
    y=merged_data_df['Income'],
    name='Income',
    marker=dict(color='rgb(158,202,225)')
)
trace2 = go.Scatter(
    x=merged_data_df['State'],
    y=merged_data_df['Value'],
    
    name='Ozone Concentration value',
    yaxis = 'y2'
)

data = [trace1, trace2]
layout = go.Layout(
    title='Income vs AQI(Ozone Concentration)',
    xaxis = dict(title='States'),
    yaxis=dict(
        title='Income'
    ),
    yaxis2=dict(
        title='AQI(ozone_concentration) value',
        titlefont=dict(
            color='rgb(153, 204, 255)'
        ),
        tickfont=dict(
            color='rgb(148, 103, 189)'
        ),
        overlaying='y',
        side='right'
    )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yamini/383.embed" height="525px" width="100%"></iframe>

# %%
#state_col = air_index_value['State']

#value_col = air_index_value['Value']
state1_col = year2003_df['StateName']
#year_col = measure83_df['ReportYear']
value_col = year2003_df['Value']

state_col = average_income_df['State']
income_col = average_income_df['Income']
value_plot= go.Bar(x = state_col, y = income_col, name = "Income",
                   marker=dict(color='rgb(158,202,225)'))



value_plot= go.Bar(x = state_col, y = value_col, name = year_col,
                   marker=dict(color='rgb(158,202,225)'))
layout = dict(title = 'Income By State',
              xaxis = dict(title = 'State'),
              yaxis = dict(title = 'Income Value'),
              )
data = [value_plot]
fig = dict(data=data,layout=layout)
py.iplot(fig)
#https://plot.ly/~yamini/293
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yamini/357.embed" height="525px" width="100%"></iframe>

# %%
trace1 = go.Bar(
    x= average_income_df['State'],
    y=average_income_df['Income'],
    name='Income',
    marker=dict(color='rgb(158,202,225)')
)
trace2 = go.Scatter(
    x=year2003_df['StateName'],
    y=year2003_df['Value'],
    
    name='Ozone Concentration value',
    yaxis = 'y2'
)

data = [trace1, trace2]
layout = go.Layout(
    title='Income vs AQI(Ozone Concentration)',
    xaxis = dict(title='States'),
    yaxis=dict(
        title='Income'
    ),
    yaxis2=dict(
        title='AQI(ozone_concentration) value',
        titlefont=dict(
            color='rgb(153, 204, 255)'
        ),
        tickfont=dict(
            color='rgb(148, 103, 189)'
        ),
        overlaying='y',
        side='right'
    )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~yamini/375.embed" height="525px" width="100%"></iframe>
